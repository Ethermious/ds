# %%
import pandas as pd
import numpy as np

data = pd.read_csv('../data/titanic3.csv')

# %%
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr().abs()[["survived"]]
# Out:
# /tmp/ipykernel_36121/1402684040.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr().abs()[["survived"]]
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
# /tmp/ipykernel_36121/3242586923.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr().abs()[["survived"]]
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055512
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# body            NaN
# relatives  0.201719

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %% [markdown]
# Below this is with the Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
# Out:
# 2023-04-23 16:11:27.559674: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-23 16:11:30.417971: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-23 16:11:30.418697: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 1s 8ms/step - loss: 0.6924 - accuracy: 0.5861
# Epoch 2/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6904 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.6860 - accuracy: 0.5861
# Epoch 4/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6768 - accuracy: 0.5861
# Epoch 5/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6611 - accuracy: 0.5861
# Epoch 6/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6387 - accuracy: 0.5861
# Epoch 7/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6151 - accuracy: 0.5861
# Epoch 8/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5963 - accuracy: 0.5861
# Epoch 9/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.5828 - accuracy: 0.5861
# Epoch 10/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5750 - accuracy: 0.5861
# Epoch 11/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.5694 - accuracy: 0.5861
# Epoch 12/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5653 - accuracy: 0.5861
# Epoch 13/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.5620 - accuracy: 0.7799
# Epoch 14/50
# 27/27 [==============================] - 0s 13ms/step - loss: 0.5587 - accuracy: 0.7799
# Epoch 15/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5561 - accuracy: 0.7847
# Epoch 16/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5534 - accuracy: 0.7895
# Epoch 17/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5515 - accuracy: 0.7883
# Epoch 18/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5495 - accuracy: 0.7859
# Epoch 19/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.5474 - accuracy: 0.7847
# Epoch 20/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5453 - accuracy: 0.7895
# Epoch 21/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5433 - accuracy: 0.7955
# Epoch 22/50
# 27/27 [==============================] - 0s 18ms/step - loss: 0.5413 - accuracy: 0.7943
# Epoch 23/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5395 - accuracy: 0.7919
# Epoch 24/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5378 - accuracy: 0.7895
# Epoch 25/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5361 - accuracy: 0.7895
# Epoch 26/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.5345 - accuracy: 0.7931
# Epoch 27/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.5328 - accuracy: 0.7919
# Epoch 28/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5314 - accuracy: 0.7931
# Epoch 29/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.5296 - accuracy: 0.7931
# Epoch 30/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5280 - accuracy: 0.8002
# Epoch 31/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.5267 - accuracy: 0.8014
# Epoch 32/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5251 - accuracy: 0.7978
# Epoch 33/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5241 - accuracy: 0.7967
# Epoch 34/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.5221 - accuracy: 0.7967
# Epoch 35/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5212 - accuracy: 0.7955
# Epoch 36/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.5200 - accuracy: 0.7955
# Epoch 37/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5189 - accuracy: 0.7943
# Epoch 38/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.5176 - accuracy: 0.7967
# Epoch 39/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5161 - accuracy: 0.7967
# Epoch 40/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5151 - accuracy: 0.7978
# Epoch 41/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.5140 - accuracy: 0.7978
# Epoch 42/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5131 - accuracy: 0.7967
# Epoch 43/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5117 - accuracy: 0.7955
# Epoch 44/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5112 - accuracy: 0.7955
# Epoch 45/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.5100 - accuracy: 0.7955
# Epoch 46/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5093 - accuracy: 0.7990
# Epoch 47/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.5080 - accuracy: 0.8002
# Epoch 48/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.5073 - accuracy: 0.8014
# Epoch 49/50
# 27/27 [==============================] - 0s 16ms/step - loss: 0.5063 - accuracy: 0.7990
# Epoch 50/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.5056 - accuracy: 0.8002

# %%
y_pred = np.rint(model.predict(X_test).flatten())
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 7/7 [==============================] - 0s 6ms/step
# 0.8133971291866029
